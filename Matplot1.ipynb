# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y = x**3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.subplot(2,2,1)
plt.plot(y**2,x**5)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %%
plt.subplot(6,6,1) #onk gula banano jai
# Out:
# <Axes: >

# %%
#object oriented way
fig = plt.figure(figsize=(20,8),dpi=100)
axis1=fig.add_axes([0.1,0.1,.4,.5])
axis1.plot(x,y)

axis2=fig.add_axes([0.3,0.4,.3,.3])
axis2.plot(x,y)

# %%
#types of plot
plt.scatter(x,y)

# %%
plt.hist(x) #histrogram
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1611f2fef90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1611f2ff230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1611f2fee40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1611f2ff4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1611f2ff620>],
#  'means': []}

# %%
#Saving plots
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basic plot.png")

# %%
#working with images , bcz it works with numpy

# %%
import matplotlib.image as mpimg

# %%
img= mpimg.imread('nigachu.jfif')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(183.5), np.float64(183.5), np.float64(-0.5))
